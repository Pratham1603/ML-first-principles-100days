# %% [markdown]
# # How to use HUGE KAGGLE DATASET in COLAB without DOWNLOAD & UPLOADING using KAGGLE API

# %% [markdown]
# kaggle -> Account -> Create new API token -> Kaggle.json file get downloaded -> uplaod it in colab

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %% [markdown]
# Add dataset api command from kaggle

# %%
# !kaggle datasets download -d wobotintelligence/face-mask-detection-dataset

# %% [markdown]
# Problem : dataset is downloaded in single zip need to extract ir so run below command

# %%
import zipfile
zip_ref = zipfile.ZipFile('face-mask-detection-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %% [markdown]
# Done!
